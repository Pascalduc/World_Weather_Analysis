# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import requests
import numpy as np
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the nearest cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list using enumerate because index in URL will cause error.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]               
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

  
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,                          
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | road town
# Processing Record 3 of Set 1 | maniwaki
# Processing Record 4 of Set 1 | kayerkan
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | margate
# Processing Record 8 of Set 1 | lucapa
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 11 of Set 1 | bereda
# Processing Record 12 of Set 1 | ishigaki
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | lenger
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | dalinghe
# City not found. Skipping...
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | taldan
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | aldan
# Processing Record 35 of Set 1 | garbsen
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | mocuba
# Processing Record 39 of Set 1 | high level
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | nuuk
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | aktau
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | uvinza
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | cam ranh
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | karratha
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | adrar
# Processing Record 5 of Set 2 | mbini
# Processing Record 6 of Set 2 | flinders
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | sao joao da barra
# Processing Record 9 of Set 2 | lata
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | yanggu
# Processing Record 17 of Set 2 | iquitos
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | mahibadhoo
# Processing Record 20 of Set 2 | gorom-gorom
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | oeiras do para
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | natal
# Processing Record 29 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint-leu
# Processing Record 31 of Set 2 | dvinskoy
# Processing Record 32 of Set 2 | caravelas
# Processing Record 33 of Set 2 | moratuwa
# Processing Record 34 of Set 2 | jining
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | alofi
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | blagoyevo
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | tautira
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | ternate
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | alexandria
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | portland
# Processing Record 3 of Set 3 | mengyin
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | lagoa
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | shaowu
# Processing Record 11 of Set 3 | sol-iletsk
# Processing Record 12 of Set 3 | wasserburg
# Processing Record 13 of Set 3 | veracruz
# Processing Record 14 of Set 3 | rio grande
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | rudbar
# Processing Record 17 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 3 | rawson
# Processing Record 19 of Set 3 | yar-sale
# Processing Record 20 of Set 3 | srednekolymsk
# Processing Record 21 of Set 3 | shingu
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | malangwa
# Processing Record 24 of Set 3 | helsinki
# Processing Record 25 of Set 3 | zeya
# Processing Record 26 of Set 3 | kapit
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 3 | aquiraz
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | ambilobe
# Processing Record 33 of Set 3 | nara
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | watsa
# Processing Record 36 of Set 3 | palimbang
# Processing Record 37 of Set 3 | bani
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | belmonte
# Processing Record 41 of Set 3 | richards bay
# Processing Record 42 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 3 | lalomanu
# City not found. Skipping...
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | martapura
# Processing Record 46 of Set 3 | bitam
# Processing Record 47 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 3 | saint-georges
# Processing Record 49 of Set 3 | comodoro rivadavia
# Processing Record 50 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | bedford
# Processing Record 3 of Set 4 | keti bandar
# Processing Record 4 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 4 | smolensk
# Processing Record 6 of Set 4 | gold coast
# Processing Record 7 of Set 4 | bozova
# Processing Record 8 of Set 4 | mount isa
# Processing Record 9 of Set 4 | tawzar
# City not found. Skipping...
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | grand gaube
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | havoysund
# Processing Record 14 of Set 4 | suhbaatar
# Processing Record 15 of Set 4 | inhambane
# Processing Record 16 of Set 4 | dabat
# Processing Record 17 of Set 4 | amga
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | mount pleasant
# Processing Record 20 of Set 4 | saint-gaudens
# Processing Record 21 of Set 4 | manacapuru
# Processing Record 22 of Set 4 | nador
# Processing Record 23 of Set 4 | lokosovo
# Processing Record 24 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 4 | santa maria
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | qasigiannguit
# Processing Record 32 of Set 4 | cayenne
# Processing Record 33 of Set 4 | aasiaat
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | shelburne
# Processing Record 36 of Set 4 | dobroye
# Processing Record 37 of Set 4 | melchor de mencos
# Processing Record 38 of Set 4 | barda
# Processing Record 39 of Set 4 | victoria
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | saint-augustin
# Processing Record 42 of Set 4 | cheney
# Processing Record 43 of Set 4 | lukovetskiy
# Processing Record 44 of Set 4 | graaff-reinet
# Processing Record 45 of Set 4 | khuzdar
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | flin flon
# Processing Record 48 of Set 4 | santo augusto
# Processing Record 49 of Set 4 | mwaya
# Processing Record 50 of Set 4 | ukiah
# Processing Record 1 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | makarov
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | arkhara
# Processing Record 10 of Set 5 | gubbi
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | sarh
# Processing Record 14 of Set 5 | chifeng
# Processing Record 15 of Set 5 | itarema
# Processing Record 16 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | ponnani
# Processing Record 18 of Set 5 | chimbote
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | xinzhou
# Processing Record 21 of Set 5 | ayagoz
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | nabire
# Processing Record 24 of Set 5 | noumea
# Processing Record 25 of Set 5 | skjervoy
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | vuktyl
# Processing Record 28 of Set 5 | lermontovka
# Processing Record 29 of Set 5 | hay river
# Processing Record 30 of Set 5 | hitiaa
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | three hills
# Processing Record 33 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 34 of Set 5 | barentu
# Processing Record 35 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | akyab
# Processing Record 38 of Set 5 | cape canaveral
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | abaete
# Processing Record 41 of Set 5 | eureka
# Processing Record 42 of Set 5 | zhicheng
# Processing Record 43 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 5 | gizo
# Processing Record 45 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 5 | sattahip
# Processing Record 47 of Set 5 | begusarai
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | kyaukse
# Processing Record 50 of Set 5 | manoel urbano
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | livingstone
# Processing Record 3 of Set 6 | kalakamati
# Processing Record 4 of Set 6 | kamenka
# Processing Record 5 of Set 6 | gari
# Processing Record 6 of Set 6 | namatanai
# Processing Record 7 of Set 6 | kudahuvadhoo
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | guangyuan
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | kieta
# Processing Record 13 of Set 6 | burica
# City not found. Skipping...
# Processing Record 14 of Set 6 | prado
# Processing Record 15 of Set 6 | amazar
# Processing Record 16 of Set 6 | muros
# Processing Record 17 of Set 6 | missoula
# Processing Record 18 of Set 6 | yenagoa
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | mwingi
# Processing Record 21 of Set 6 | miramar
# Processing Record 22 of Set 6 | porto novo
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | pechenga
# Processing Record 25 of Set 6 | kabanjahe
# Processing Record 26 of Set 6 | zhanaozen
# Processing Record 27 of Set 6 | whitley bay
# Processing Record 28 of Set 6 | dalbandin
# Processing Record 29 of Set 6 | pazardzik
# City not found. Skipping...
# Processing Record 30 of Set 6 | turukhansk
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | bay roberts
# Processing Record 33 of Set 6 | surt
# Processing Record 34 of Set 6 | eyl
# Processing Record 35 of Set 6 | ust-nera
# Processing Record 36 of Set 6 | muisne
# Processing Record 37 of Set 6 | goure
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | tazovskiy
# Processing Record 40 of Set 6 | urcos
# Processing Record 41 of Set 6 | hobyo
# Processing Record 42 of Set 6 | komsomolskiy
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | gander
# Processing Record 45 of Set 6 | pangai
# Processing Record 46 of Set 6 | puerto escondido
# Processing Record 47 of Set 6 | emerald
# Processing Record 48 of Set 6 | odweyne
# Processing Record 49 of Set 6 | kaseda
# Processing Record 50 of Set 6 | lamu
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 7 | wenling
# Processing Record 5 of Set 7 | udachnyy
# Processing Record 6 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 7 | santo antonio do ica
# Processing Record 8 of Set 7 | techiman
# Processing Record 9 of Set 7 | vila
# Processing Record 10 of Set 7 | saldanha
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | havelock
# Processing Record 14 of Set 7 | lanivtsi
# Processing Record 15 of Set 7 | kavieng
# Processing Record 16 of Set 7 | urazovka
# Processing Record 17 of Set 7 | marathon
# Processing Record 18 of Set 7 | birjand
# Processing Record 19 of Set 7 | kahului
# Processing Record 20 of Set 7 | darab
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | isangel
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | pokhara
# Processing Record 25 of Set 7 | biak
# Processing Record 26 of Set 7 | kota kinabalu
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | nyuksenitsa
# Processing Record 29 of Set 7 | sept-iles
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | santa cruz de la palma
# Processing Record 32 of Set 7 | constitucion
# Processing Record 33 of Set 7 | gambela
# Processing Record 34 of Set 7 | kasane
# Processing Record 35 of Set 7 | faya
# Processing Record 36 of Set 7 | anloga
# Processing Record 37 of Set 7 | bang saphan
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | qui nhon
# Processing Record 40 of Set 7 | kokoda
# Processing Record 41 of Set 7 | bousse
# Processing Record 42 of Set 7 | praia
# Processing Record 43 of Set 7 | gamba
# Processing Record 44 of Set 7 | tual
# Processing Record 45 of Set 7 | batemans bay
# Processing Record 46 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 7 | tarakan
# Processing Record 48 of Set 7 | jatai
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | gurupa
# Processing Record 1 of Set 8 | vao
# Processing Record 2 of Set 8 | puksoozero
# Processing Record 3 of Set 8 | skibbereen
# Processing Record 4 of Set 8 | latung
# Processing Record 5 of Set 8 | gemena
# Processing Record 6 of Set 8 | te anau
# Processing Record 7 of Set 8 | astipalaia
# City not found. Skipping...
# Processing Record 8 of Set 8 | palkaka
# City not found. Skipping...
# Processing Record 9 of Set 8 | alice springs
# Processing Record 10 of Set 8 | mecca
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | yasnogorsk
# Processing Record 13 of Set 8 | honiara
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | xinyu
# Processing Record 16 of Set 8 | ugoofaaru
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | barrie
# Processing Record 19 of Set 8 | magadan
# Processing Record 20 of Set 8 | camacha
# Processing Record 21 of Set 8 | kemijarvi
# Processing Record 22 of Set 8 | gao
# Processing Record 23 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 8 | rio formoso
# Processing Record 25 of Set 8 | almenara
# Processing Record 26 of Set 8 | jinxiang
# Processing Record 27 of Set 8 | vestmanna
# Processing Record 28 of Set 8 | brae
# Processing Record 29 of Set 8 | redlands
# Processing Record 30 of Set 8 | newport
# Processing Record 31 of Set 8 | ngaglik
# Processing Record 32 of Set 8 | independencia
# Processing Record 33 of Set 8 | tabou
# Processing Record 34 of Set 8 | severo-kurilsk
# Processing Record 35 of Set 8 | jackson
# Processing Record 36 of Set 8 | hervey bay
# Processing Record 37 of Set 8 | jalu
# Processing Record 38 of Set 8 | marawi
# Processing Record 39 of Set 8 | marsh harbour
# Processing Record 40 of Set 8 | cape coast
# Processing Record 41 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 8 | shubarkuduk
# Processing Record 43 of Set 8 | dingle
# Processing Record 44 of Set 8 | morondava
# Processing Record 45 of Set 8 | hokitika
# Processing Record 46 of Set 8 | longyearbyen
# Processing Record 47 of Set 8 | sri aman
# Processing Record 48 of Set 8 | vidalia
# Processing Record 49 of Set 8 | tucuman
# Processing Record 50 of Set 8 | miram shah
# Processing Record 1 of Set 9 | davila
# Processing Record 2 of Set 9 | yumen
# Processing Record 3 of Set 9 | kiruna
# Processing Record 4 of Set 9 | cap malheureux
# Processing Record 5 of Set 9 | sao miguel do tapuio
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | baghdad
# Processing Record 8 of Set 9 | west bay
# Processing Record 9 of Set 9 | kemin
# Processing Record 10 of Set 9 | tilichiki
# Processing Record 11 of Set 9 | champerico
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | kampot
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 9 | bucerias
# Processing Record 17 of Set 9 | praia da vitoria
# Processing Record 18 of Set 9 | yarada
# Processing Record 19 of Set 9 | belyy yar
# Processing Record 20 of Set 9 | pringsewu
# Processing Record 21 of Set 9 | sayyan
# Processing Record 22 of Set 9 | rundu
# Processing Record 23 of Set 9 | ampanihy
# Processing Record 24 of Set 9 | waingapu
# Processing Record 25 of Set 9 | kourou
# Processing Record 26 of Set 9 | joinville
# Processing Record 27 of Set 9 | vestmannaeyjar
# Processing Record 28 of Set 9 | ahipara
# Processing Record 29 of Set 9 | cooma
# Processing Record 30 of Set 9 | honningsvag
# Processing Record 31 of Set 9 | san patricio
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | agva
# City not found. Skipping...
# Processing Record 34 of Set 9 | jand
# Processing Record 35 of Set 9 | port hedland
# Processing Record 36 of Set 9 | grootfontein
# Processing Record 37 of Set 9 | great falls
# Processing Record 38 of Set 9 | haimen
# Processing Record 39 of Set 9 | camopi
# Processing Record 40 of Set 9 | maldonado
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | tezu
# Processing Record 43 of Set 9 | lewes
# Processing Record 44 of Set 9 | ciudad guayana
# Processing Record 45 of Set 9 | marakkanam
# Processing Record 46 of Set 9 | teguldet
# Processing Record 47 of Set 9 | ust-omchug
# Processing Record 48 of Set 9 | leningradskiy
# Processing Record 49 of Set 9 | dukat
# Processing Record 50 of Set 9 | barguzin
# Processing Record 1 of Set 10 | teya
# Processing Record 2 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 10 | saint marys
# Processing Record 4 of Set 10 | karatau
# Processing Record 5 of Set 10 | veselynove
# Processing Record 6 of Set 10 | nishihara
# Processing Record 7 of Set 10 | mareeba
# Processing Record 8 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 10 | ostrovnoy
# Processing Record 10 of Set 10 | callaway
# Processing Record 11 of Set 10 | dauphin
# Processing Record 12 of Set 10 | coihaique
# Processing Record 13 of Set 10 | andenes
# Processing Record 14 of Set 10 | almaznyy
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | glendive
# Processing Record 17 of Set 10 | pell city
# Processing Record 18 of Set 10 | kerema
# Processing Record 19 of Set 10 | salinopolis
# Processing Record 20 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 10 | coahuayana
# Processing Record 22 of Set 10 | sakakah
# Processing Record 23 of Set 10 | cedro
# Processing Record 24 of Set 10 | pavlodar
# Processing Record 25 of Set 10 | vardo
# Processing Record 26 of Set 10 | tekeli
# Processing Record 27 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 28 of Set 10 | ahuimanu
# Processing Record 29 of Set 10 | kupang
# Processing Record 30 of Set 10 | talara
# Processing Record 31 of Set 10 | korla
# Processing Record 32 of Set 10 | san andres
# Processing Record 33 of Set 10 | tecoanapa
# Processing Record 34 of Set 10 | tashla
# Processing Record 35 of Set 10 | luena
# Processing Record 36 of Set 10 | mandan
# Processing Record 37 of Set 10 | tura
# Processing Record 38 of Set 10 | berlevag
# Processing Record 39 of Set 10 | hami
# Processing Record 40 of Set 10 | auki
# Processing Record 41 of Set 10 | olinda
# Processing Record 42 of Set 10 | joson
# Processing Record 43 of Set 10 | kefamenanu
# Processing Record 44 of Set 10 | ust-maya
# Processing Record 45 of Set 10 | khatima
# Processing Record 46 of Set 10 | leh
# Processing Record 47 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 10 | manbij
# Processing Record 49 of Set 10 | sakaiminato
# Processing Record 50 of Set 10 | luanda
# Processing Record 1 of Set 11 | palu
# Processing Record 2 of Set 11 | kosh-agach
# Processing Record 3 of Set 11 | carmen del parana
# Processing Record 4 of Set 11 | sabha
# Processing Record 5 of Set 11 | nouakchott
# Processing Record 6 of Set 11 | kerzhenets
# City not found. Skipping...
# Processing Record 7 of Set 11 | pedernales
# Processing Record 8 of Set 11 | zhoucheng
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | bambanglipuro
# Processing Record 11 of Set 11 | kiama
# Processing Record 12 of Set 11 | verkhnyaya inta
# Processing Record 13 of Set 11 | kosum phisai
# Processing Record 14 of Set 11 | ust-shonosha
# Processing Record 15 of Set 11 | puerto cabezas
# Processing Record 16 of Set 11 | anadyr
# Processing Record 17 of Set 11 | udomlya
# Processing Record 18 of Set 11 | oranjemund
# Processing Record 19 of Set 11 | santiago
# Processing Record 20 of Set 11 | khasan
# Processing Record 21 of Set 11 | bushehr
# Processing Record 22 of Set 11 | fukue
# Processing Record 23 of Set 11 | chicama
# Processing Record 24 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 11 | zambezi
# Processing Record 26 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 11 | cosoleacaque
# Processing Record 28 of Set 11 | placido de castro
# Processing Record 29 of Set 11 | sechura
# Processing Record 30 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 11 | winslow
# Processing Record 32 of Set 11 | erenhot
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | zhuhai
# Processing Record 36 of Set 11 | san quintin
# Processing Record 37 of Set 11 | kashi
# Processing Record 38 of Set 11 | carhuaz
# Processing Record 39 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 40 of Set 11 | miracema do tocantins
# Processing Record 41 of Set 11 | bardiyah
# Processing Record 42 of Set 11 | beruwala
# Processing Record 43 of Set 11 | harindanga
# Processing Record 44 of Set 11 | kingaroy
# Processing Record 45 of Set 11 | port blair
# Processing Record 46 of Set 11 | najran
# Processing Record 47 of Set 11 | pak phanang
# Processing Record 48 of Set 11 | bhadrachalam
# Processing Record 49 of Set 11 | adre
# Processing Record 50 of Set 11 | general roca
# Processing Record 1 of Set 12 | sao jose da coroa grande
# Processing Record 2 of Set 12 | cockburn town
# Processing Record 3 of Set 12 | kozachi laheri
# Processing Record 4 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 5 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 12 | grindavik
# Processing Record 7 of Set 12 | kondinskoye
# Processing Record 8 of Set 12 | kembolcha
# Processing Record 9 of Set 12 | troitskoye
# Processing Record 10 of Set 12 | gerash
# Processing Record 11 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 12 | wuning
# Processing Record 13 of Set 12 | la rioja
# Processing Record 14 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 12 | san-pedro
# Processing Record 16 of Set 12 | colesberg
# Processing Record 17 of Set 12 | barquisimeto
# Processing Record 18 of Set 12 | coxim
# Processing Record 19 of Set 12 | marystown
# Processing Record 20 of Set 12 | beyneu
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | batagay
# Processing Record 23 of Set 12 | sabang
# Processing Record 24 of Set 12 | progreso
# Processing Record 25 of Set 12 | campo formoso
# Processing Record 26 of Set 12 | beloha
# Processing Record 27 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 12 | marzuq
# Processing Record 29 of Set 12 | puno
# Processing Record 30 of Set 12 | todos santos
# Processing Record 31 of Set 12 | nisia floresta
# Processing Record 32 of Set 12 | necochea
# Processing Record 33 of Set 12 | tarko-sale
# Processing Record 34 of Set 12 | coleraine
# Processing Record 35 of Set 12 | maryville
# Processing Record 36 of Set 12 | svetlaya
# Processing Record 37 of Set 12 | bagdarin
# Processing Record 38 of Set 12 | cabedelo
# Processing Record 39 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 12 | abha
# Processing Record 41 of Set 12 | sistranda
# Processing Record 42 of Set 12 | kaa-khem
# Processing Record 43 of Set 12 | aykhal
# Processing Record 44 of Set 12 | hue
# Processing Record 45 of Set 12 | baruun-urt
# Processing Record 46 of Set 12 | baijiantan
# Processing Record 47 of Set 12 | makakilo city
# Processing Record 48 of Set 12 | nogales
# Processing Record 49 of Set 12 | tolland
# Processing Record 50 of Set 12 | benton harbor
# Processing Record 1 of Set 13 | taft
# Processing Record 2 of Set 13 | zyryanka
# Processing Record 3 of Set 13 | besikduzu
# Processing Record 4 of Set 13 | kenitra
# Processing Record 5 of Set 13 | dumra
# Processing Record 6 of Set 13 | mangrol
# Processing Record 7 of Set 13 | sao francisco do sul
# Processing Record 8 of Set 13 | noyabrsk
# Processing Record 9 of Set 13 | sorland
# Processing Record 10 of Set 13 | nizwa
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | bosaso
# Processing Record 13 of Set 13 | kuryk
# Processing Record 14 of Set 13 | teeli
# Processing Record 15 of Set 13 | khorixas
# Processing Record 16 of Set 13 | charters towers
# Processing Record 17 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 13 | rioja
# Processing Record 19 of Set 13 | kuala kangsar
# Processing Record 20 of Set 13 | batagay-alyta
# Processing Record 21 of Set 13 | porto torres
# Processing Record 22 of Set 13 | piazza armerina
# Processing Record 23 of Set 13 | chatra
# Processing Record 24 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 13 | baykit
# Processing Record 26 of Set 13 | sao gabriel da cachoeira
# Processing Record 27 of Set 13 | yokadouma
# Processing Record 28 of Set 13 | mayo
# Processing Record 29 of Set 13 | saint-pierre
# Processing Record 30 of Set 13 | samandag
# Processing Record 31 of Set 13 | miri
# Processing Record 32 of Set 13 | tanout
# Processing Record 33 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 13 | hohhot
# Processing Record 35 of Set 13 | boali
# Processing Record 36 of Set 13 | kirovskiy
# Processing Record 37 of Set 13 | riyadh
# Processing Record 38 of Set 13 | blackwater
# Processing Record 39 of Set 13 | zhob
# Processing Record 40 of Set 13 | morant bay
# Processing Record 41 of Set 13 | enshi
# Processing Record 42 of Set 13 | krynychky
# Processing Record 43 of Set 13 | beno-yurt
# City not found. Skipping...
# Processing Record 44 of Set 13 | port lincoln
# Processing Record 45 of Set 13 | mezen
# Processing Record 46 of Set 13 | cururupu
# Processing Record 47 of Set 13 | pochutla
# Processing Record 48 of Set 13 | ushtobe
# Processing Record 49 of Set 13 | marfino
# Processing Record 50 of Set 13 | korsakov
# Processing Record 1 of Set 14 | ulladulla
# Processing Record 2 of Set 14 | beaverlodge
# Processing Record 3 of Set 14 | mbinga
# Processing Record 4 of Set 14 | lasa
# Processing Record 5 of Set 14 | caraguatatuba
# Processing Record 6 of Set 14 | pauini
# Processing Record 7 of Set 14 | erzin
# Processing Record 8 of Set 14 | eganville
# Processing Record 9 of Set 14 | caucaia
# Processing Record 10 of Set 14 | manastirea casin
# City not found. Skipping...
# Processing Record 11 of Set 14 | nome
# Processing Record 12 of Set 14 | padang
# Processing Record 13 of Set 14 | yerbogachen
# Processing Record 14 of Set 14 | geraldton
# Processing Record 15 of Set 14 | tiznit
# Processing Record 16 of Set 14 | okha
# Processing Record 17 of Set 14 | filingue
# Processing Record 18 of Set 14 | maceio
# Processing Record 19 of Set 14 | tenenkou
# Processing Record 20 of Set 14 | bahia blanca
# Processing Record 21 of Set 14 | nanlong
# Processing Record 22 of Set 14 | montague
# Processing Record 23 of Set 14 | lethem
# Processing Record 24 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 14 | nanzhou
# Processing Record 27 of Set 14 | scottsbluff
# Processing Record 28 of Set 14 | uvalde
# Processing Record 29 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 14 | kirkland lake
# Processing Record 31 of Set 14 | palmer
# Processing Record 32 of Set 14 | maragogi
# Processing Record 33 of Set 14 | goderich
# Processing Record 34 of Set 14 | villarrica
# Processing Record 35 of Set 14 | picota
# Processing Record 36 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 14 | pechora
# Processing Record 38 of Set 14 | sao felix do xingu
# Processing Record 39 of Set 14 | vostok
# Processing Record 40 of Set 14 | manggar
# Processing Record 41 of Set 14 | price
# Processing Record 42 of Set 14 | sovetskiy
# Processing Record 43 of Set 14 | carnot
# Processing Record 44 of Set 14 | volax
# Processing Record 45 of Set 14 | taoudenni
# Processing Record 46 of Set 14 | pisco
# Processing Record 47 of Set 14 | poronaysk
# Processing Record 48 of Set 14 | buchanan
# Processing Record 49 of Set 14 | zhigansk
# Processing Record 50 of Set 14 | bouna
# Processing Record 1 of Set 15 | mao
# Processing Record 2 of Set 15 | evensk
# Processing Record 3 of Set 15 | goundam
# Processing Record 4 of Set 15 | bethanien
# Processing Record 5 of Set 15 | saint-joseph
# Processing Record 6 of Set 15 | linhares
# Processing Record 7 of Set 15 | palana
# Processing Record 8 of Set 15 | tevriz
# Processing Record 9 of Set 15 | ust-karsk
# Processing Record 10 of Set 15 | hachinohe
# Processing Record 11 of Set 15 | zabol
# Processing Record 12 of Set 15 | asyut
# Processing Record 13 of Set 15 | imbituba
# Processing Record 14 of Set 15 | asau
# Processing Record 15 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 15 | abu dhabi
# Processing Record 17 of Set 15 | bundaberg
# Processing Record 18 of Set 15 | juegang
# Processing Record 19 of Set 15 | jishui
# Processing Record 20 of Set 15 | hambantota
# Processing Record 21 of Set 15 | krasnoselkup
# Processing Record 22 of Set 15 | kirovohrad
# Processing Record 23 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 15 | tsumeb
# Processing Record 25 of Set 15 | wismar
# Processing Record 26 of Set 15 | salalah
# Processing Record 27 of Set 15 | santa lucia
# Processing Record 28 of Set 15 | wunsiedel
# Processing Record 29 of Set 15 | plettenberg bay
# Processing Record 30 of Set 15 | yeppoon
# Processing Record 31 of Set 15 | blagoveshchenka
# Processing Record 32 of Set 15 | eirunepe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tiksi      RU  71.6872  128.8694    -25.76        99         100
# 1  Road Town      VG  18.4167  -64.6167     25.00        83          40
# 2   Maniwaki      CA  46.3834  -75.9660     -1.00        24           0
# 3   Kayerkan      RU  69.3497   87.7602    -25.52        87          25
# 4    Mataura      NZ -46.1927  168.8643     13.89        67         100
# 5   Hermanus      ZA -34.4187   19.2345     17.22        66         100
# 6    Margate      GB  51.3813    1.3862      6.67        72          28
# 7     Lucapa      AO  -8.4192   20.7447     18.11        97          78
# 8    Rikitea      PF -23.1203 -134.9692     25.47        74          47
# 9     Bereda      ES  43.2686   -7.5406     13.00       100          90
#
#    Wind Speed       Description
# 0        3.78   overcast clouds
# 1        3.60  scattered clouds
# 2        3.09         clear sky
# 3        2.69  scattered clouds
# 4        3.58        light rain
# 5        3.58   overcast clouds
# 6        1.79  scattered clouds
# 7        0.63     broken clouds
# 8        4.72        light rain
# 9        0.51   overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv('WeatherPy_Database.csv', index_label="City_ID")
